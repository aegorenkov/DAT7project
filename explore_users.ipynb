# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from os import chdir

# %%
from loaders.user_timelines import UserTimelineLoader
from loaders.user_loader import UserLoader

# %%
# %matplotlib inline

# %%
# %pwd
# Out:
# u'C:\\Users\\Alexander\\Documents\\Programming\\DAT7\\DAT7project'

# %%
DIRECTORY = r'C:\Users\Alexander\Documents\Programming\DAT7\DAT7project'
chdir(DIRECTORY)

#Load in data that determines user categories
random_users = UserLoader(DIRECTORY, 'random').users
random_users.rename(columns = {'id':'user_id'}, inplace=True)
random_users['user_type'] = 0
random_users.head(10)
# Out:
#            created_at                                        description  \
# 0 2012-12-11 05:57:32                                                NaN
# 1 2012-12-12 15:07:29  Environmental engineers, Secondary School Manager
# 2 2012-12-12 18:35:09                                                NaN
# 3 2012-12-13 18:14:45                                                NaN
# 4 2010-01-03 14:57:55                                                NaN
# 5 2012-12-18 18:21:22                                                NaN
# 6 2012-12-20 13:18:24                                                NaN
# 7 2012-12-21 06:43:49                                                NaN
# 8 2010-01-08 07:03:08                                                NaN
# 9 2012-12-23 12:48:07                                                NaN
#
#    favourites_count  followers_count  friends_count  geo_enabled     user_id  \
# 0               NaN              NaN              1          NaN  1003414406
# 1               NaN                6             17          NaN  1006572037
# 2                 4                4             57          NaN  1007005704
# 3                 9               51             20            1  1009418101
# 4               NaN                3             20          NaN   101494003
# 5               NaN              NaN              2          NaN  1020351756
# 6               NaN              NaN              5          NaN  1024249081
# 7               NaN              NaN              6          NaN  1025809502
# 8               NaN               62             19          NaN   102912757
# 9               NaN                1             10          NaN  1030501914
#
#   lang  listed_count         location    ...    profile_text_color protected  \
# 0   en           NaN              NaN    ...                333333     False
# 1   en           NaN     USA New York    ...                333333     False
# 2   ru           NaN  Санкт-Петербург    ...                333333     False
# 3   ar           NaN              NaN    ...                362720      True
# 4   en           NaN              NaN    ...                333333     False
# 5   ar           NaN              NaN    ...                333333     False
# 6   en           NaN              NaN    ...                333333     False
# 7   ru           NaN              NaN    ...                333333     False
# 8   en           NaN              NaN    ...                333333     False
# 9   en           NaN    antipolo city    ...                333333     False
#
#        screen_name                                             status  \
# 0         pjaouwas  {u'lang': u'tl', u'favorited': False, u'trunca...
# 1    SoreSeducer7k  {u'lang': u'en', u'favorited': False, u'trunca...
# 2         jokerint  {u'lang': u'ru', u'favorited': False, u'trunca...
# 3  ahmedabualfoto1                                                NaN
# 4        silviatri                                                NaN
# 5    aziz_alsuwait  {u'lang': u'ar', u'favorited': False, u'trunca...
# 6  danilomaguengue  {u'lang': u'en', u'favorited': False, u'trunca...
# 7      MegurineLin  {u'lang': u'ru', u'favorited': False, u'trunca...
# 8         nadiyaah  {u'lang': u'en', u'favorited': False, u'trunca...
# 9        cam_oliva                                                NaN
#
#   statuses_count time_zone                   url utc_offset verified user_type
# 0              1       NaN                   NaN        NaN      NaN         0
# 1              1       NaN                   NaN        NaN      NaN         0
# 2             10   Yerevan  http://t.co/008pP33D      14400      NaN         0
# 3           4221    Athens                   NaN      10800      NaN         0
# 4            NaN       NaN                   NaN        NaN      NaN         0
# 5            271       NaN                   NaN        NaN      NaN         0
# 6            218       NaN                   NaN        NaN      NaN         0
# 7              1       NaN                   NaN        NaN      NaN         0
# 8              3       NaN                   NaN        NaN      NaN         0
# 9            NaN       NaN                   NaN        NaN      NaN         0
#
# [10 rows x 28 columns]

# %%
retweeters = UserLoader(DIRECTORY, 'retweeter').users
retweeters.rename(columns = {'id':'user_id'}, inplace=True)
retweeters['user_type'] = 1
retweeters.head()
# Out:
#            created_at                                        description  \
# 0 2010-01-15 22:01:00       The whimsicle whispers of a wandering wreck.
# 1 2013-01-18 05:53:34             QueensU'15 • makeup enthusiast • 849er
# 2 2013-01-18 17:44:33  Sometimes I think I am a superhero. That happe...
# 3 2010-02-02 04:48:28                            love fuckin. fuck love.
# 4 2013-01-24 06:51:48  Don't mind my life worry about yours,KHOSI4LIF...
#
#    favourites_count  followers_count  friends_count  geo_enabled     user_id  \
# 0                83              133            340            1   105269169
# 1              4115              165            181            1  1100130618
# 2             15107              302            327            1  1101563028
# 3              1364             2577           1960          NaN   110614388
# 4               116              444            340            1  1116145537
#
#   lang  listed_count                    location    ...    profile_text_color  \
# 0   en             2                         NaN    ...                666666
# 1   en             2         Johnstown, Ontario     ...                333333
# 2   en           NaN                         NaN    ...                333333
# 3   en            45  HIGH  .. on my Polo horse     ...                FF0000
# 4   en             3       Short left&turn right    ...                333333
#
#   protected      screen_name  \
# 0     False            iNabz
# 1     False   TaylorMcNizzle
# 2     False          Kal_Sea
# 3     False  accidentalDOPE_
# 4     False        MkhondoSt
#
#                                               status statuses_count  \
# 0  {u'lang': u'en', u'favorited': False, u'trunca...           5067
# 1  {u'lang': u'en', u'favorited': False, u'trunca...          10145
# 2  {u'lang': u'en', u'favorited': False, u'retwee...           6251
# 3  {u'lang': u'en', u'favorited': False, u'retwee...          72225
# 4  {u'lang': u'fr', u'favorited': False, u'trunca...          14287
#
#                     time_zone                     url utc_offset verified  \
# 0                         NaN                     NaN        NaN      NaN
# 1                         NaN                     NaN        NaN      NaN
# 2  Eastern Time (US & Canada)                     NaN     -14400      NaN
# 3  Eastern Time (US & Canada)                     NaN     -14400      NaN
# 4                         NaN  http://t.co/yzXxVe2hvD        NaN      NaN
#
#   user_type
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
#
# [5 rows x 28 columns]

# %%
#Remove any potential id collisions
random_users = random_users[~random_users['user_id'].isin(retweeters['user_id'])]

data = pd.concat([random_users, retweeters], ignore_index=True)
data.head()
# Out:
#            created_at                                        description  \
# 0 2012-12-11 05:57:32                                                NaN
# 1 2012-12-12 15:07:29  Environmental engineers, Secondary School Manager
# 2 2012-12-12 18:35:09                                                NaN
# 3 2012-12-13 18:14:45                                                NaN
# 4 2010-01-03 14:57:55                                                NaN
#
#    favourites_count  followers_count  friends_count  geo_enabled     user_id  \
# 0               NaN              NaN              1          NaN  1003414406
# 1               NaN                6             17          NaN  1006572037
# 2                 4                4             57          NaN  1007005704
# 3                 9               51             20            1  1009418101
# 4               NaN                3             20          NaN   101494003
#
#   lang  listed_count         location    ...    profile_text_color protected  \
# 0   en           NaN              NaN    ...                333333     False
# 1   en           NaN     USA New York    ...                333333     False
# 2   ru           NaN  Санкт-Петербург    ...                333333     False
# 3   ar           NaN              NaN    ...                362720      True
# 4   en           NaN              NaN    ...                333333     False
#
#        screen_name                                             status  \
# 0         pjaouwas  {u'lang': u'tl', u'favorited': False, u'trunca...
# 1    SoreSeducer7k  {u'lang': u'en', u'favorited': False, u'trunca...
# 2         jokerint  {u'lang': u'ru', u'favorited': False, u'trunca...
# 3  ahmedabualfoto1                                                NaN
# 4        silviatri                                                NaN
#
#   statuses_count time_zone                   url utc_offset verified user_type
# 0              1       NaN                   NaN        NaN      NaN         0
# 1              1       NaN                   NaN        NaN      NaN         0
# 2             10   Yerevan  http://t.co/008pP33D      14400      NaN         0
# 3           4221    Athens                   NaN      10800      NaN         0
# 4            NaN       NaN                   NaN        NaN      NaN         0
#
# [5 rows x 28 columns]

# %%
data.groupby('user_type').created_at.min()
# Out:
# user_type
# 0   2007-06-23 01:42:25
# 1   2008-04-07 16:11:05
# Name: created_at, dtype: datetime64[ns]

# %%
data.groupby('user_type').created_at.max()
# Out:
# user_type
# 0   2015-04-26 01:10:39
# 1   2015-05-02 17:32:19
# Name: created_at, dtype: datetime64[ns]

# %%
data[['favourites_count', 'followers_count', 'friends_count', 'user_type']].groupby('user_type').describe()
# Out:
#                  favourites_count  followers_count  friends_count
# user_type
# 0         count        313.000000       637.000000     797.000000
#           mean         241.706070       182.233909      97.958595
#           std         1550.719518      2666.980809     439.592516
#           min            1.000000         1.000000       1.000000
#           25%            2.000000         2.000000       5.000000
#           50%            6.000000         6.000000      17.000000
#           75%           50.000000        29.000000      60.000000
#           max        26208.000000     65941.000000    8985.000000
# 1         count        281.000000       284.000000     285.000000
#           mean        4600.053381      2056.151408    1421.263158
#           std        11314.935907      8352.283350    6954.866044
#           min            1.000000         9.000000       2.000000
#           25%          270.000000       167.000000     192.000000
#           50%         1235.000000       344.000000     328.000000
#           75%         3770.000000       771.000000     686.000000
#           max       118597.000000     89416.000000   84915.000000

# %% [markdown]
# Users who retweet personal victories are more active than users who do not

# %% [markdown]
# ##How many users of each type do we have?

# %%
data.user_type.count()
# Out:
# 1299

# %%
data[data.user_type==1].user_type.count()
# Out:
# 285

# %%
data[data.user_type==0].user_type.count()
# Out:
# 1014
